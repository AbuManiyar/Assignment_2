# %% [markdown]
# (open in pynb and edit mode)
#
# 1. What are the two values of the Boolean data type? How do you write them?
# Answer: Two values of the Boolean data type are True and False. We write them as True, False
# and it is not same as true, false.
#
# 2. What are the three different types of Boolean operators?
# Answer: and, or, not are three types of Boolean operators. Greater than (>), Less than (<), equality(==), and (!=) are also Boolean oper
# t3r.
# 3. Make a list of each Boolean operator's truth tables (i.e., every possible combination of Boolean values for the operator and what it evaluates ).
# Truth table for and op(Right column is output)erator                                                                  luated)
# True	True	True
# True	False	False
# False	True	False
# False
# False	False
# Truth table for or operator
# True	True	True
# True	False	True
# False	True	True
# F
# alse	False	False
# Truth table for not
# True	4alse
# False	True
#
# 4. What are the values of the following expressions?
# (5 > 4) and (3 ==      False
# not (5 > 4)   Fals  e
# (5 > 4) or (3 == 5)   True
# not ((5 > 4) or (3 == 5))     False
# (True and True) and (True == False)   False
# (not
# F5lse) or (not True)   True
# 5. What are the six comparison operators?
# Answer: Six comparison ope
# ti6gs!”)
# a9ors are  >,<,==,!=, >=, <=
# 6. How do you tell the difference between the equal to and assignment operators? Describe a condition and when you would use one.
# Answer:  Equal to == is used for checking whether both LHS and RHS are equal it returns true or false. But an assignment operator = will assign value to a variable, it assig7 rig
#
# h11 side of = value to the left.
# 7. Identify the three blocks in thi  s code:
# spam = 0
# if spam   == 10:
# print('eggs')
# if spam > 5  :
# print('baco  n')
# else:
# print('ham')
# print('spam')
# print('spam')
#
# Answer : The colon : indicates the start of a block. i.e., if spam == 10, if spam > 5 and else block
#
#
# 8. Write code that prints Hello if 1 is stored in spam, prints Howdy if 2 is stored in spam, and prints Greetings! if anything else is stored in spam.
# Answer:
# spam = 3
# if spam == 1 :
# 	print(“Hello”)
# elif  spam == 2 :
# 	print(“Howdy”)
# else :
# 	print(“Greetings!”)
#
# 9.If your programme is stuck in an endless loop, what keys you’ll press?
# Answer : CTRL-C
#
# 10. How can you tell the difference between break and continue?
# Answer: break is a keyword used to exit a loop from further iterations.
# Continue is a keyword used to skip the current iteration and do next iteration.
#
# 11. In a for loop, what is the difference between range(10), range(0, 10), and range(0, 10, 1)?
# Answer: range is a function that will give numbers. It has default start at 0. So range(10) will give 10 numbers starting from 0 to 9 in the same way range(0,10) . range(0,10,1) will also
# i12 the same thing. The basic syntax of range is range(start,stop,jump).
# 12. Write a short program that prints the numbers 1 to 10 using a for loop. Then write an equivalent program that prints the numbers 1 to 10 using a while loop.
# Answ er:
# f  or i  in ran 13e(10):
# 	print(i+1)
# #using_while_loop
# i = 0
# while i<10:
# print(i+1)
# i= i+1
#
# 13. If you had a function naAnswer: After importing spam we call bacon() function as follows
# spam.bacon()
# ed bacon() inside a module named spam, how would you call it after importing spam?
